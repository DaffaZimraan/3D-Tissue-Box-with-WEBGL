# %% [markdown]
# <a href="https://colab.research.google.com/github/DaffaZimraan/3D-Tissue-Box-with-WEBGL/blob/main/YOLO_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Library
# !pip install ultralytics
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Load Model
model = YOLO('yolov8n.pt')

# %%
# Show original image
img_path = 'assets/image1.jpg'
img = Image.open(img_path)
plt.title('Original Image')
plt.axis('off')
plt.imshow(img)

# %%
# Detect image
img_path = 'assets/image1.jpg'
results = model(img_path)
# Out:
# image 1/1 /content/assets/image1.jpg: 640x448 1 person, 1 dog, 306.7ms
# Speed: 4.3ms preprocess, 306.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)

# %%
# Show output
results[0].plot()
# Out:
# array([[[173, 174, 178],
#         [169, 171, 172],
#         [168, 167, 169],
#         ...,
#         [111, 123, 117],
#         [120, 127, 122],
#         [126, 130, 125]],
#
#        [[173, 174, 178],
#         [169, 171, 172],
#         [168, 167, 169],
#         ...,
#         [ 94, 107, 105],
#         [ 71,  80,  77],
#         [ 64,  69,  68]],
#
#        [[173, 174, 178],
#         [169, 171, 172],
#         [168, 167, 169],
#         ...,
#         [ 60,  75,  78],
#         [ 28,  40,  42],
#         [  3,  12,  16]],
#
#        ...,
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [157, 157, 157],
#         ...,
#         [143, 141, 140],
#         [136, 137, 135],
#         [134, 132, 131]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [157, 157, 157],
#         ...,
#         [153, 151, 150],
#         [152, 150, 149],
#         [151, 149, 148]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [157, 157, 157],
# ...

# %%
# Print detected classes
for box in results[0].boxes:
  cls_id = int(box.cls[0])
  conf = float(box.conf[0])
  print(f'Class: {model.names[cls_id]}, Confidence: {conf:.2f}')
# Out:
# Class: dog, Confidence: 0.91
# Class: person, Confidence: 0.74
